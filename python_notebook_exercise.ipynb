# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## Athanasia Nikolaou
# ## data scientist

# %% [markdown]
# _I am interested in data science because after my studies in physics I find data fascinating and would like to apply a lot of methods in order to reveal insights in them_

# %% [markdown]
# ### My code makes a plot of a sinusoidal curve

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.arange(0,7.0,0.2)
y=np.sin(x)

plt.plot(x,y)

# %% [markdown]
# -  Bulleted item
# -  Bulleted item 2
# -  Bulleted item 3
#
# 1. Numbered Item
# 1. Numbered item 2
# 1. Numbered item 3
#
# __[Here is a lik to a science blog](http://www.tumblr.com/dropsofsciences)__
